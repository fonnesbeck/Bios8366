# %% [markdown]
# # IPython
#
# **IPython** is an enhanced Python shell which provides a more robust and productive development environment for users. There are several key features that set it apart from the standard Python shell .
#
# ### History
#
# In IPython, all your inputs and outputs are saved. There are two variables named `In` and `Out` which are assigned as you work with your results. All outputs are saved automatically to variables of the form `_N`, where `N` is the prompt number, and inputs to `_iN`. This allows you to recover quickly the result of a prior computation by referring to its number even if you forgot to store it as a variable.

# %%
np.sin(4)**2
# Out:
# 0.57275001690430671

# %%
_1
# Out:
# 0.57275001690430671

# %%
_i1
# Out:
# u'np.sin(4)**2'

# %%
_1 / 4.
# Out:
# 0.14318750422607668

# %% [markdown]
# ### Introspection
#
# If you want details regarding the properties and functionality of any Python objects currently loaded into IPython, you can use the `?` to reveal any details that are available:

# %%
some_dict = {}
some_dict?

# %% [markdown]
# If available, additional detail is provided with two question marks, including the source code of the object itself.

# %%
from numpy.linalg import cholesky
cholesky??

# %% [markdown]
# This syntax can also be used to search namespaces with wildcards (\*).

# %%
plt.*plot*?

# %% [markdown]
# ### Tab completion
#
# Because IPython allows for introspection, it is able to afford the user the ability to tab-complete commands that have been partially typed. This is done by pressing the `<tab>` key at any point during the process of typing a command:

# %%
np.
# Out:
#   File "<ipython-input-10-a58a88215da2>", line 1
#     np.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# This can even be used to help with specifying arguments to functions, which can sometimes be difficult to remember:

# %%
plt.hist(
# Out:
#   File "<ipython-input-11-53b0ee2a5cbd>", line 1
#     plt.hist(
#              ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### System commands
#
# In IPython, you can type `ls` to see your files or `cd` to change directories, just like you would at a regular system prompt:

# %%
pwd
# Out:
# u'/Users/fonnescj/Bios366/notebooks'

# %%
ls ~/Downloads/*py
# Out:
# ls: /Users/fonnescj/Downloads/*py: No such file or directory

# %% [markdown]
# Virtually any system command can be accessed by prepending `!`, which passes any subsequent command directly to the OS.

# %%
# !locate Bayes | grep pdf
# Out:
# /Users/fonnescj/Archive/Bayes Lecture 1.pdf
# /Users/fonnescj/Archive/Bayes Lecture 2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/Image-Beta_distribution_pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/Image-Gamma_distribution_pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/QuickLook/Preview.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-110.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-111.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-112.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-113.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-114.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-115.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-116.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-117.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-26.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-27.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-28.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-41.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-42.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-43.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-44.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-45.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-46.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-47.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-48.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-49.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-50.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-51.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-52.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-53.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-54.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-55.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-56.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-57.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-58.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-59.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-60.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-61.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-62.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-63.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-64.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-65.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-66.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-67.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-68.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-69.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-70.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-71.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-72.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-73.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-74.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-75.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-76.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-77.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-78.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-80.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-81.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-82.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-84.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-85.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-86.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-87.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-88.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-89.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-90.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-91.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-92.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-93.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-94.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-95.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-96.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-97.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-98.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage-99.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/droppedImage.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation-19.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation-20.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation-21.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation-22.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation-23.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation-24.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation-25.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation-26.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation-27.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day1.key/equation.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/QuickLook/Preview.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/Rplot.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/Rplot1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/Rplot2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/binomial_pdf_3.tiff
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-10.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-101.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-102.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-11.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-111.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-116.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-117.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-118.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-119.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-12.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-120.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-121.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-122.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-123.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-124.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-125.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-126.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-127.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-128.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-129.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-13.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-130.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-131.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-132.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-133.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-134.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-135.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-136.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-137.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-138.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-139.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-14.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-140.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-141.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-142.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-143.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-144.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-145.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-146.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-147.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-148.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-149.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-15.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-150.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-151.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-152.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-153.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-154.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-155.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-156.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-157.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-158.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-159.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-16.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-160.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-161.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-162.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-163.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-164.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-165.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-166.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-167.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-168.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-169.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-17.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-18.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-19.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-20.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-21.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-22.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-23.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-24.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-25.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-26.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-27.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-28.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-29.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-30.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-31.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-6.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-7.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-8.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-80.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-83.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-84.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-85.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-86.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-87.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-9.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-93.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-94.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-95.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-96.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-98.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage-99.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/droppedImage.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/equation-15.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Day2.key/equation-16.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Python.key/droppedImage-1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Python.key/droppedImage-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Python.key/droppedImage-3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Python.key/droppedImage.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/T.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-10.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-12.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-13.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-16.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-17.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-18.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-19.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-20.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-21.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-24.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-25.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-26.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-30.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-31.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-32.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-33.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-35.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-36.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-37.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-39.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-40.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-41.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-42.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-6.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-7.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-8.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage-9.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/Seminar series talk.key/droppedImage.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/10__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/1__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/1__#$!@%!#__Pasted Graphic.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/2__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/2__#$!@%!#__Pasted Graphic.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/3__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/4__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/5__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/6__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/7__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/8__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/9__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/outline.oo3/Pasted Graphic.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/python_notes.pages/droppedImage-1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/python_notes.pages/droppedImage-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/stat_seminar_talk.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/Image-Beta_distribution_pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/Image-Gamma_distribution_pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-10.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-100.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-101.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-102.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-103.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-104.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-105.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-106.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-107.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-108.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-109.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-11.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-110.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-111.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-112.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-113.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-114.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-115.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-119.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-12.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-120.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-122.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-123.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-124.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-125.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-126.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-13.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-130.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-131.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-133.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-134.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-135.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-136.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-137.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-138.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-139.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-14.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-140.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-141.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-142.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-143.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-144.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-145.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-146.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-147.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-148.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-149.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-15.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-16.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-17.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-18.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-19.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-20.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-21.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-22.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-23.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-24.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-25.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-26.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-27.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-28.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-29.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-30.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-31.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-32.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-33.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-34.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-35.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-36.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-37.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-38.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-39.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-40.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-41.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-42.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-43.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-44.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-45.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-46.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-47.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-48.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-49.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-50.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-51.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-52.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-53.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-54.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-55.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-56.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-57.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-58.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-59.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-6.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-60.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-61.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-62.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-63.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-64.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-65.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-66.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-67.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-68.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-69.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-7.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-70.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-71.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-72.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-73.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-74.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-75.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-76.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-77.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-78.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-79.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-8.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-80.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-81.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-82.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-83.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-84.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-85.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-86.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-87.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-88.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-89.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-9.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-90.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-91.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-92.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-93.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-94.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-95.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-96.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-97.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-98.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage-99.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/droppedImage.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pages/test.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/2008 Archive/workshop_book.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/ERG Slides 1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/ERG Slides 2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/ERG Slides 3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/ERG Slides 4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/ERG Slides 5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/Introduction to Bayesian Statistics.oo3/Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/ERG Workshop/Link 2002 The Journal of Wildlife Management.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/1-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/2-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/3-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/4-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/5-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/6-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/BUGS_notes.pages/Preview of “winbugsho.pdf”.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/BUGS_notes.pages/compile.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/BUGS_notes.pages/droppedImage-1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/BUGS_notes.pages/samples.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/BUGS_notes.pages/update.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/BUGS_notes.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Bayes_Unit1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Bayes_Unit2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Bayes_Unit3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Bayes_Unit4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Bayes_Unit5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Bayes_Unit6.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Bayes_Unit7.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Bayes_Unit8.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Bayes_Unit9.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/DIC-slides.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Gelman_solutions2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/HWsln3_4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-10.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-11.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-12.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-15.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-16.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-19.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-20.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-21.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-22.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage-5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/droppedImage.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-10.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-11.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-12.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-13.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-14.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-15.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-16.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-17.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-18.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-19.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-20.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-21.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-24.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-25.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-6.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-7.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-8.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation-9.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 1.key/equation.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-17.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-25.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-26.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-27.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-30.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-32.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-33.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-34.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-35.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-36.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-37.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-38.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-39.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-40.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-41.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-42.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-43.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-44.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-45.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-46.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-48.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-49.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-50.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-51.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-53.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-55.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Lecture 2.key/droppedImage-56.pdf
# ...
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/98__#$!@%!#__equation.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/98__#$!@%!#__equation.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/99__#$!@%!#__equation.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/99__#$!@%!#__equation.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/9__#$!@%!#__Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/9__#$!@%!#__Pasted Graphic.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/9__#$!@%!#__equation.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/9__#$!@%!#__equation.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/Pasted Graphic.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/Pasted Graphic.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/equation.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/equation.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/geweke1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/geweke1.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/geweke2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/STAT 431 Course Outline.oo3/geweke2.pdf.tiff
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/The Basics of Markov chain Monte Carlo.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Vol1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Vol2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/Vol3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/beta.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/beta2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/final.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/final.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/final_solutions.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/final_solutions.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/final_solutions_STAT431.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/geweke1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/geweke2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/green_bayes.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/green_bayes_MARKED.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image0.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image10.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image11.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image12.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image13.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image14.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image15.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image16.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image17.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image18.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image19.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image20.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image21.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image22.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image23.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image24.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image25.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image26.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image27.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image28.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image29.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image30.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image31.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image32.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image33.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image6.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image7.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image8.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project.pages/image9.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image0.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image10.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image11.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image12.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image13.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image14.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image15.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image16.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image17.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image18.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image19.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image20.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image21.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image22.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image23.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image24.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image25.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image26.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image27.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image28.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image29.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image30.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image31.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image32.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image33.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image6.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image7.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image8.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pages/image9.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/lim_project_MARKED.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/manual14.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/mcmc-notes-4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/mcmc_review.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/midterm2002.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/missing.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/python_notes.pages/droppedImage-1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/python_notes.pages/droppedImage-2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/questions1.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/questions1_solutions.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/questions2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/questions2.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/questions2_solutions.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/questions3.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/questions3_solutions.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/reading7-Ella.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2008 Archive/reading7-Tess.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Gelman_Ch1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Gelman_Ch2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Gelman_Ch3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 10.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 5.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 6.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 7.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 8.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Lecture 9.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/R_notes.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/Rplots.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/assignment1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/assignment1.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/assignment2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/assignment2.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/assignment3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/definetti.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/final2009.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/final2009.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/final2009_solutions.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/final2009_solutions.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/2009 Archive/solutions2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 2/Crystal-assignment2_fixed.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 2/Darren-assignment2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 2/Ross Assignment 2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 2/TUREK stat431 assignment 2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 2/Will-assigment2.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 2/Yahya-Assignment 2-STAT431.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 3/Crystal-assignment3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 3/Darren-assignment3.1.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 3/RAH assignment 3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 3/TUREK - STAT431 assignment3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 3/Will-Assign3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 3/Yahya-Assig3f.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Assignment 3/assignment3_joseph_20100511.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Gibbs plots/MC hist.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Gibbs plots/MC trace.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Gibbs plots/MCMC 1000.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Gibbs plots/MCMC 10000.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Gibbs plots/acf.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Projects/431Outline.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Projects/STAT431 Project Proposal.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Projects/TUREK -- STAT431 Project Proposal.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/Projects/outline.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/assignment1.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/assignment3.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/fig10_3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/fig10_4.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/final2010.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/final2010.pdfsync
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/final2010_pre.pdf
# /Users/fonnescj/Archive/Bayes Workshop/STAT 431/q3.pdf
# /Users/fonnescj/Archive/Bayes Workshop/philosophy_chapter.pdf
# /Users/fonnescj/Archive/Bayes Workshop/radon.pdf
# /Users/fonnescj/Archive/Hartmann Meta-analysis/We conducted a Bayesian meta.pdf
# /Users/fonnescj/Bios366/resources/Albert-R-Bayes.pdf
# /Users/fonnescj/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/Chapter1_Introduction/Chapter1_Introduction.pdf
# /Users/fonnescj/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/Chapter2_MorePyMC/MorePyMC.pdf
# /Users/fonnescj/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/Chapter3_MCMC/IntroMCMC.pdf
# /Users/fonnescj/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/PDF/June82013.pdf

# %% [markdown]
# You can even use Python variables in commands sent to the OS:

# %%
file_type = 'csv'
# !ls ../data/*$file_type
# Out:
# ../data/baseball.csv           ../data/microbiome_missing.csv
# ../data/cdystonia.csv          ../data/vlbw.csv
# ../data/microbiome.csv

# %% [markdown]
# The output of a system command using the exclamation point syntax can be assigned to a Python variable.

# %%
data_files = !ls ../data/microbiome/

# %%
data_files
# Out:
# ['MID1.xls',
#  'MID2.xls',
#  'MID3.xls',
#  'MID4.xls',
#  'MID5.xls',
#  'MID6.xls',
#  'MID7.xls',
#  'MID8.xls',
#  'MID9.xls',
#  'metadata.xls']

# %% [markdown]
# ## Qt Console
#
# If you type at the system prompt:
#
#     $ ipython qtconsole
#
# instead of opening in a terminal, IPython will start a graphical console that at first sight appears just like a terminal, but which is in fact much more capable than a text-only terminal.  This is a specialized terminal designed for interactive scientific work, and it supports full multi-line editing with color highlighting and graphical calltips for functions, it can keep multiple IPython sessions open simultaneously in tabs, and when scripts run it can display the figures inline directly in the work area.
#
# ![qtconsole](files/images/qtconsole.png)

# %% [markdown]
# ## iPython Notebook
#
# IPython includes the **HTML notebook** featured here, as well as support for **interactive data visualization** and easy high-performance **parallel computing**.

# %%
def f(x):
    return (x-3)*(x-5)*(x-7)+85

import numpy as np
x = np.linspace(0, 10, 200)
y = f(x)
plot(x,y)

# %% [markdown]
# The notebook lets you document your workflow using either HTML or Markdown.
#
# The IPython Notebook consists of two related components:
#
# * A JSON based Notebook document format for recording and distributing Python code and rich text.
# * A web-based user interface for authoring and running notebook documents.
#
# The Notebook can be used by starting the Notebook server with the command:
#
#     $ ipython notebook
#
# This initiates an **iPython engine**, which is a Python instance that takes Python commands over a network connection. If we want to enable inline plotting of figures via Matplotlib, we can add a `--pylab inline` flag to the command.
#
# The **IPython controller** provides an interface for working with a set of engines, to which one or more **iPython clients** can connect.
#
# The Notebook gives you everything that a browser gives you. For example, you can embed images, videos, or entire websites.

# %%
from IPython.display import HTML
HTML("<iframe src=http://fonnesbeck.github.io/Bios366 width=700 height=350></iframe>")
# Out:
# <iframe src=http://fonnesbeck.github.io/Bios366 width=700 height=350></iframe>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("BS4Wd5rwNwE")
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="http://www.youtube.com/embed/BS4Wd5rwNwE"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Remote Code
#
# Use `%load` to add remote code

# %% [markdown]
# ### Mathjax Support
#
# Mathjax ia a javascript implementation of LaTeX that allows equations to be embedded into HTML. For example, this markup:
#
#     """$$ \int_{a}^{b} f(x)\, dx \approx \frac{1}{2} \sum_{k=1}^{N} \left( x_{k} - x_{k-1} \right) \left( f(x_{k}) + f(x_{k-1}) \right). $$"""
#
# becomes this:
#
# $$
# \int_{a}^{b} f(x)\, dx \approx \frac{1}{2} \sum_{k=1}^{N} \left( x_{k} - x_{k-1} \right) \left( f(x_{k}) + f(x_{k-1}) \right).
# $$

# %% [markdown]
# ## SymPy Support
#
# SymPy is a Python library for symbolic mathematics. It supports:
#
# * polynomials
# * calculus
# * solving equations
# * discrete math
# * matrices

# %%
from sympy import *
# %load_ext sympyprinting
x, y = symbols("x y")

# %%
eq = ((x+y)**2 * (x+1))
eq
# Out:
#                2
# (x + 1)⋅(x + y)

# %%
expand(eq)
# Out:
#  3      2      2      2            2
# x  + 2⋅x ⋅y + x  + x⋅y  + 2⋅x⋅y + y

# %%
(1/cos(x)).series(x, 0, 6)
# Out:
#      2      4
#     x    5⋅x     ⎛ 6⎞
# 1 + ── + ──── + O⎝x ⎠
#     2     24

# %% [markdown]
# ### Magic functions
#
# IPython has a set of predefined ‘magic functions’ that you can call with a command line style syntax. These include:
#
# * `%run`
# * `%edit`
# * `%debug`
# * `%timeit`
# * `%paste`
# * `%load_ext`

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %colors  %config  %connect_info  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %install_default_config  %install_ext  %install_profiles  %killbgscripts  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %lsmagic  %macro  %magic  %man  %matplotlib  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %run  %save  %sc  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%latex  %%perl  %%prun  %%pypy  %%python  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# Timing the execution of code; the `timeit` magic exists both in line and cell form:

# %%
# %timeit np.linalg.eigvals(np.random.rand(100,100))
# Out:
# 100 loops, best of 3: 9.51 ms per loop

# %%
# %%timeit a = np.random.rand(100, 100)
np.linalg.eigvals(a)
# Out:
# 100 loops, best of 3: 8.81 ms per loop

# %% [markdown]
# IPython also creates aliases for a few common interpreters, such as bash, ruby, perl, etc.
#
# These are all equivalent to `%%script <name>`

# %%
# %%ruby
# puts "Hello from Ruby #{RUBY_VERSION}"
# Out:
# Hello from Ruby 1.8.7

# %%
# %%bash
# echo "hello from $BASH"
# Out:
# hello from /bin/bash

# %% [markdown]
# IPython has an `rmagic` extension that contains a some magic functions for working with R via rpy2. This extension can be loaded using the `%load_ext` magic as follows:

# %%
# %load_ext rmagic

# %%
x,y = arange(10), random.normal(size=10)

# %%
# %%R -i x,y -o XYcoef
# lm.fit <- lm(y~x)
# par(mfrow=c(2,2))
# print(summary(lm.fit))
# plot(lm.fit)
# XYcoef <- coef(lm.fit)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5124 -0.5600 -0.3624  0.9568  1.2839
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.2598     0.6062   0.429    0.680
# x            -0.0706     0.1136  -0.622    0.551
#
# Residual standard error: 1.031 on 8 degrees of freedom
# Multiple R-squared:  0.04609,	Adjusted R-squared:  -0.07315
# F-statistic: 0.3865 on 1 and 8 DF,  p-value: 0.5514

# %%
XYcoef
# Out:
# [ 0.25982295 -0.07060319]

# %% [markdown]
# ## Exporting and Converting Notebooks
#
# In IPython 1.0, one can convert an `.ipynb` notebook document file into various static formats via the `nbconvert` tool. Currently, nbconvert is a command line tool, run as a script using IPython.

# %%
# !ipython nbconvert --to latex Section2_1-IPython.ipynb
# Out:
# [NbConvertApp] Using existing profile dir: u'/Users/fonnescj/.ipython/profile_default'
# [NbConvertApp] Converting notebook Section2_1-IPython.ipynb to latex
# [NbConvertApp] Support files will be in Section2_1-IPython_files/
# [NbConvertApp] Loaded template latex_article.tplx
# [NbConvertApp] Writing 45340 bytes to Section2_1-IPython.tex

# %%
# %load Section2_1-IPython.tex

# %%
% Header, overrides base

    % Make sure that the sphinx doc style knows who it inherits from.
    \def\sphinxdocclass{article}

    % Declare the document class
    \documentclass[letterpaper,10pt,english]{/Library/Python/2.7/site-packages/sphinx/texinputs/sphinxhowto}

    % Imports
    \usepackage[utf8]{inputenc}
    \DeclareUnicodeCharacter{00A0}{\\nobreakspace}
    \usepackage[T1]{fontenc}
    \usepackage{babel}
    \usepackage{times}
    \usepackage{import}
    \usepackage[Bjarne]{/Library/Python/2.7/site-packages/sphinx/texinputs/fncychap}
    \usepackage{longtable}
    \usepackage{/Library/Python/2.7/site-packages/sphinx/texinputs/sphinx}
    \usepackage{multirow}

    \usepackage{amsmath}
    \usepackage{amssymb}
    \usepackage{ucs}
    \usepackage{enumerate}

    % Used to make the Input/Output rules follow around the contents.
    \usepackage{needspace}

    % Pygments requirements
    \usepackage{fancyvrb}
    \usepackage{color}
    % ansi colors additions
    \definecolor{darkgreen}{rgb}{.12,.54,.11}
    \definecolor{lightgray}{gray}{.95}
    \definecolor{brown}{rgb}{0.54,0.27,0.07}
    \definecolor{purple}{rgb}{0.5,0.0,0.5}
    \definecolor{darkgray}{gray}{0.25}
    \definecolor{lightred}{rgb}{1.0,0.39,0.28}
    \definecolor{lightgreen}{rgb}{0.48,0.99,0.0}
    \definecolor{lightblue}{rgb}{0.53,0.81,0.92}
    \definecolor{lightpurple}{rgb}{0.87,0.63,0.87}
    \definecolor{lightcyan}{rgb}{0.5,1.0,0.83}

    % Needed to box output/input
    \usepackage{tikz}
        \usetikzlibrary{calc,arrows,shadows}
    \usepackage[framemethod=tikz]{mdframed}

    \usepackage{alltt}

    % Used to load and display graphics
    \usepackage{graphicx}
    \graphicspath{ {figs/} }
    \usepackage[Export]{adjustbox} % To resize

    % used so that images for notebooks which have spaces in the name can still be included
    \usepackage{grffile}


    % For formatting output while also word wrapping.
    \usepackage{listings}
    \lstset{breaklines=true}
    \lstset{basicstyle=\small\ttfamily}
    \def\smaller{\fontsize{9.5pt}{9.5pt}\selectfont}

    # %Pygments definitions
    
\makeatletter
\def\PY@reset{\let\PY@it=\relax \let\PY@bf=\relax%
    \let\PY@ul=\relax \let\PY@tc=\relax%
    \let\PY@bc=\relax \let\PY@ff=\relax}
\def\PY@tok#1{\csname PY@tok@#1\endcsname}
\def\PY@toks#1+{\ifx\relax#1\empty\else%
    \PY@tok{#1}\expandafter\PY@toks\fi}
\def\PY@do#1{\PY@bc{\PY@tc{\PY@ul{%
    \PY@it{\PY@bf{\PY@ff{#1}}}}}}}
\def\PY#1#2{\PY@reset\PY@toks#1+\relax+\PY@do{#2}}

\expandafter\def\csname PY@tok@gd\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.63,0.00,0.00}{##1}}}
\expandafter\def\csname PY@tok@gu\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.50,0.00,0.50}{##1}}}
\expandafter\def\csname PY@tok@gt\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.00,0.25,0.82}{##1}}}
\expandafter\def\csname PY@tok@gs\endcsname{\let\PY@bf=\textbf}
\expandafter\def\csname PY@tok@gr\endcsname{\def\PY@tc##1{\textcolor[rgb]{1.00,0.00,0.00}{##1}}}
\expandafter\def\csname PY@tok@cm\endcsname{\let\PY@it=\textit\def\PY@tc##1{\textcolor[rgb]{0.25,0.50,0.50}{##1}}}
\expandafter\def\csname PY@tok@vg\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.10,0.09,0.49}{##1}}}
\expandafter\def\csname PY@tok@m\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.40,0.40,0.40}{##1}}}
\expandafter\def\csname PY@tok@mh\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.40,0.40,0.40}{##1}}}
\expandafter\def\csname PY@tok@go\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.50,0.50,0.50}{##1}}}
\expandafter\def\csname PY@tok@ge\endcsname{\let\PY@it=\textit}
\expandafter\def\csname PY@tok@vc\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.10,0.09,0.49}{##1}}}
\expandafter\def\csname PY@tok@il\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.40,0.40,0.40}{##1}}}
\expandafter\def\csname PY@tok@cs\endcsname{\let\PY@it=\textit\def\PY@tc##1{\textcolor[rgb]{0.25,0.50,0.50}{##1}}}
\expandafter\def\csname PY@tok@cp\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.74,0.48,0.00}{##1}}}
\expandafter\def\csname PY@tok@gi\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.00,0.63,0.00}{##1}}}
\expandafter\def\csname PY@tok@gh\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.00,0.50}{##1}}}
\expandafter\def\csname PY@tok@ni\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.60,0.60,0.60}{##1}}}
\expandafter\def\csname PY@tok@nl\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.63,0.63,0.00}{##1}}}
\expandafter\def\csname PY@tok@nn\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.00,1.00}{##1}}}
\expandafter\def\csname PY@tok@no\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.53,0.00,0.00}{##1}}}
\expandafter\def\csname PY@tok@na\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.49,0.56,0.16}{##1}}}
\expandafter\def\csname PY@tok@nb\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@nc\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.00,1.00}{##1}}}
\expandafter\def\csname PY@tok@nd\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.67,0.13,1.00}{##1}}}
\expandafter\def\csname PY@tok@ne\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.82,0.25,0.23}{##1}}}
\expandafter\def\csname PY@tok@nf\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.00,0.00,1.00}{##1}}}
\expandafter\def\csname PY@tok@si\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.73,0.40,0.53}{##1}}}
\expandafter\def\csname PY@tok@s2\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.73,0.13,0.13}{##1}}}
\expandafter\def\csname PY@tok@vi\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.10,0.09,0.49}{##1}}}
\expandafter\def\csname PY@tok@nt\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@nv\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.10,0.09,0.49}{##1}}}
\expandafter\def\csname PY@tok@s1\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.73,0.13,0.13}{##1}}}
\expandafter\def\csname PY@tok@sh\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.73,0.13,0.13}{##1}}}
\expandafter\def\csname PY@tok@sc\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.73,0.13,0.13}{##1}}}
\expandafter\def\csname PY@tok@sx\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@bp\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@c1\endcsname{\let\PY@it=\textit\def\PY@tc##1{\textcolor[rgb]{0.25,0.50,0.50}{##1}}}
\expandafter\def\csname PY@tok@kc\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@c\endcsname{\let\PY@it=\textit\def\PY@tc##1{\textcolor[rgb]{0.25,0.50,0.50}{##1}}}
\expandafter\def\csname PY@tok@mf\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.40,0.40,0.40}{##1}}}
\expandafter\def\csname PY@tok@err\endcsname{\def\PY@bc##1{\setlength{\fboxsep}{0pt}\fcolorbox[rgb]{1.00,0.00,0.00}{1,1,1}{\strut ##1}}}
\expandafter\def\csname PY@tok@kd\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@ss\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.10,0.09,0.49}{##1}}}
\expandafter\def\csname PY@tok@sr\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.73,0.40,0.53}{##1}}}
\expandafter\def\csname PY@tok@mo\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.40,0.40,0.40}{##1}}}
\expandafter\def\csname PY@tok@kn\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@mi\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.40,0.40,0.40}{##1}}}
\expandafter\def\csname PY@tok@gp\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.00,0.50}{##1}}}
\expandafter\def\csname PY@tok@o\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.40,0.40,0.40}{##1}}}
\expandafter\def\csname PY@tok@kr\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@s\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.73,0.13,0.13}{##1}}}
\expandafter\def\csname PY@tok@kp\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@w\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.73,0.73,0.73}{##1}}}
\expandafter\def\csname PY@tok@kt\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.69,0.00,0.25}{##1}}}
\expandafter\def\csname PY@tok@ow\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.67,0.13,1.00}{##1}}}
\expandafter\def\csname PY@tok@sb\endcsname{\def\PY@tc##1{\textcolor[rgb]{0.73,0.13,0.13}{##1}}}
\expandafter\def\csname PY@tok@k\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.00,0.50,0.00}{##1}}}
\expandafter\def\csname PY@tok@se\endcsname{\let\PY@bf=\textbf\def\PY@tc##1{\textcolor[rgb]{0.73,0.40,0.13}{##1}}}
\expandafter\def\csname PY@tok@sd\endcsname{\let\PY@it=\textit\def\PY@tc##1{\textcolor[rgb]{0.73,0.13,0.13}{##1}}}

\def\PYZbs{\char`\\}
\def\PYZus{\char`\_}
\def\PYZob{\char`\{}
\def\PYZcb{\char`\}}
\def\PYZca{\char`\^}
\def\PYZam{\char`\&}
\def\PYZlt{\char`\<}
\def\PYZgt{\char`\>}
\def\PYZsh{\char`\#}
\def\PYZpc{\char`\%}
\def\PYZdl{\char`\$}
\def\PYZti{\char`\~}
% for compatibility with earlier versions
\def\PYZat{@}
\def\PYZlb{[}
\def\PYZrb{]}
\makeatother


    # %Set pygments styles if needed...
    
        \definecolor{nbframe-border}{rgb}{0.867,0.867,0.867}
        \definecolor{nbframe-bg}{rgb}{0.969,0.969,0.969}
        \definecolor{nbframe-in-prompt}{rgb}{0.0,0.0,0.502}
        \definecolor{nbframe-out-prompt}{rgb}{0.545,0.0,0.0}

        \newenvironment{ColorVerbatim}
        {\begin{mdframed}[%
            roundcorner=1.0pt, %
            backgroundcolor=nbframe-bg, %
            userdefinedwidth=1\linewidth, %
            leftmargin=0.1\linewidth, %
            innerleftmargin=0pt, %
            innerrightmargin=0pt, %
            linecolor=nbframe-border, %
            linewidth=1pt, %
            usetwoside=false, %
            everyline=true, %
            innerlinewidth=3pt, %
            innerlinecolor=nbframe-bg, %
            middlelinewidth=1pt, %
            middlelinecolor=nbframe-bg, %
            outerlinewidth=0.5pt, %
            outerlinecolor=nbframe-border, %
            needspace=0pt
        ]}
        {\end{mdframed}}
        
        \newenvironment{InvisibleVerbatim}
        {\begin{mdframed}[leftmargin=0.1\linewidth,innerleftmargin=3pt,innerrightmargin=3pt, userdefinedwidth=1\linewidth, linewidth=0pt, linecolor=white, usetwoside=false]}
        {\end{mdframed}}

        \renewenvironment{Verbatim}[1][\unskip]
        {\begin{alltt}\smaller}
        {\end{alltt}}
    

    % Help prevent overflowing lines due to urls and other hard-to-break 
    % entities.  This doesn't catch everything...
    \sloppy

    % Document level variables
    \title{Section2\_1-IPython}
    \date{August 20, 2013}
    \release{}
    \author{Unknown Author}
    \renewcommand{\releasename}{}

    % TODO: Add option for the user to specify a logo for his/her export.
    \newcommand{\sphinxlogo}{}

    % Make the index page of the document.
    \makeindex

    % Import sphinx document type specifics.
     


% Body

    % Start of the document
    \begin{document}

        
            \maketitle
        

        


        
        \section{IPython}

\textbf{IPython} is an enhanced Python shell which provides a more
robust and productive development environment for users. There are
several key features that set it apart from the standard Python shell .

\subsubsection{History}

In IPython, all your inputs and outputs are saved. There are two
variables named \texttt{In} and \texttt{Out} which are assigned as you
work with your results. All outputs are saved automatically to variables
of the form \texttt{\_N}, where \texttt{N} is the prompt number, and
inputs to \texttt{\_iN}. This allows you to recover quickly the result
of a prior computation by referring to its number even if you forgot to
store it as a variable.

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{np}\PY{o}{.}\PY{n}{sin}\PY{p}{(}\PY{l+m+mi}{4}\PY{p}{)}\PY{o}{*}\PY{o}{*}\PY{l+m+mi}{2}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{\PYZus{}28}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{\PYZus{}i28}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{\PYZus{}28} \PY{o}{/} \PY{l+m+mf}{4.}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
\subsubsection{Introspection}

If you want details regarding the properties and functionality of any
Python objects currently loaded into IPython, you can use the \texttt{?}
to reveal any details that are available:

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{some\PYZus{}dict} \PY{o}{=} \PY{p}{\PYZob{}}\PY{p}{\PYZcb{}}
\PY{n}{some\PYZus{}dict}\PY{err}{?}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
If available, additional detail is provided with two question marks,
including the source code of the object itself.

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{k+kn}{from} \PY{n+nn}{numpy.linalg} \PY{k+kn}{import} \PY{n}{cholesky}
\PY{n}{cholesky}\PY{err}{?}\PY{err}{?}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
This syntax can also be used to search namespaces with wildcards (*).

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{plt}\PY{o}{.}\PY{o}{*}\PY{n}{plot}\PY{o}{*}\PY{err}{?}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
\subsubsection{Tab completion}

Because IPython allows for introspection, it is able to afford the user
the ability to tab-complete commands that have been partially typed.
This is done by pressing the \texttt{\textless{}tab\textgreater{}} key
at any point during the process of typing a command:

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{np}\PY{o}{.}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
This can even be used to help with specifying arguments to functions,
which can sometimes be difficult to remember:

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{plt}\PY{o}{.}\PY{n}{hist}\PY{p}{(}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
\subsubsection{System commands}

In IPython, you can type \texttt{ls} to see your files or \texttt{cd} to
change directories, just like you would at a regular system prompt:

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{pwd}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{ls} \PY{o}{\PYZti{}}\PY{o}{/}\PY{n}{Downloads}\PY{o}{/}\PY{o}{*}\PY{n}{py}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
Virtually any system command can be accessed by prepending \texttt{!},
which passes any subsequent command directly to the OS.

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{!}locate Bayes | grep pdf
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
You can even use Python variables in commands sent to the OS:

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{file\PYZus{}type} \PY{o}{=} \PY{l+s}{'}\PY{l+s}{csv}\PY{l+s}{'}
\PY{o}{!}ls ../data/*\PY{n+nv}{\PYZdl{}file\PYZus{}type}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
The output of a system command using the exclamation point syntax can be
assigned to a Python variable.

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{data\PYZus{}files} \PY{o}{=} \PY{err}{!}\PY{n}{ls} \PY{o}{.}\PY{o}{.}\PY{o}{/}\PY{n}{data}\PY{o}{/}\PY{n}{microbiome}\PY{o}{/}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{data\PYZus{}files}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
\subsection{Qt Console}

If you type at the system prompt:

\begin{verbatim}
$ ipython qtconsole
\end{verbatim}

instead of opening in a terminal, IPython will start a graphical console
that at first sight appears just like a terminal, but which is in fact
much more capable than a text-only terminal. This is a specialized
terminal designed for interactive scientific work, and it supports full
multi-line editing with color highlighting and graphical calltips for
functions, it can keep multiple IPython sessions open simultaneously in
tabs, and when scripts run it can display the figures inline directly in
the work area.

\begin{figure}[htbp]
\centering
\includegraphics{files/images/qtconsole.png}
\caption{qtconsole}
\end{figure}\subsection{iPython Notebook}

IPython includes the \textbf{HTML notebook} featured here, as well as
support for \textbf{interactive data visualization} and easy
high-performance \textbf{parallel computing}.

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{k}{def} \PY{n+nf}{f}\PY{p}{(}\PY{n}{x}\PY{p}{)}\PY{p}{:}
    \PY{k}{return} \PY{p}{(}\PY{n}{x}\PY{o}{-}\PY{l+m+mi}{3}\PY{p}{)}\PY{o}{*}\PY{p}{(}\PY{n}{x}\PY{o}{-}\PY{l+m+mi}{5}\PY{p}{)}\PY{o}{*}\PY{p}{(}\PY{n}{x}\PY{o}{-}\PY{l+m+mi}{7}\PY{p}{)}\PY{o}{+}\PY{l+m+mi}{85}

\PY{k+kn}{import} \PY{n+nn}{numpy} \PY{k+kn}{as} \PY{n+nn}{np}
\PY{n}{x} \PY{o}{=} \PY{n}{np}\PY{o}{.}\PY{n}{linspace}\PY{p}{(}\PY{l+m+mi}{0}\PY{p}{,} \PY{l+m+mi}{10}\PY{p}{,} \PY{l+m+mi}{200}\PY{p}{)}
\PY{n}{y} \PY{o}{=} \PY{n}{f}\PY{p}{(}\PY{n}{x}\PY{p}{)}
\PY{n}{plot}\PY{p}{(}\PY{n}{x}\PY{p}{,}\PY{n}{y}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
The notebook lets you document your workflow using either HTML or
Markdown.

The IPython Notebook consists of two related components:

\begin{itemize}
\item
  A JSON based Notebook document format for recording and distributing
  Python code and rich text.
\item
  A web-based user interface for authoring and running notebook
  documents.
\end{itemize}

The Notebook can be used by starting the Notebook server with the
command:

\begin{verbatim}
$ ipython notebook
\end{verbatim}

This initiates an \textbf{iPython engine}, which is a Python instance
that takes Python commands over a network connection. If we want to
enable inline plotting of figures via Matplotlib, we can add a
\texttt{-{}-pylab inline} flag to the command.

The \textbf{IPython controller} provides an interface for working with a
set of engines, to which one or more \textbf{iPython clients} can
connect.

The Notebook gives you everything that a browser gives you. For example,
you can embed images, videos, or entire websites.

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{k+kn}{from} \PY{n+nn}{IPython.display} \PY{k+kn}{import} \PY{n}{HTML}
\PY{n}{HTML}\PY{p}{(}\PY{l+s}{"}\PY{l+s}{\PYZlt{}iframe src=http://fonnesbeck.github.io/Bios366 width=700 height=350\PYZgt{}\PYZlt{}/iframe\PYZgt{}}\PY{l+s}{"}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{k+kn}{from} \PY{n+nn}{IPython.display} \PY{k+kn}{import} \PY{n}{YouTubeVideo}
\PY{n}{YouTubeVideo}\PY{p}{(}\PY{l+s}{"}\PY{l+s}{BS4Wd5rwNwE}\PY{l+s}{"}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
\subsubsection{Remote Code}

Use \texttt{\%load} to add remote code\subsubsection{Mathjax Support}

Mathjax ia a javascript implementation of LaTeX that allows equations to
be embedded into HTML. For example, this markup:

\begin{verbatim}
"""$$ \int_{a}^{b} f(x)\, dx \approx \frac{1}{2} \sum_{k=1}^{N} \left( x_{k} - x_{k-1} \right) \left( f(x_{k}) + f(x_{k-1}) \right). $$"""
\end{verbatim}

becomes this:

\[
\int_{a}^{b} f(x)\, dx \approx \frac{1}{2} \sum_{k=1}^{N} \left( x_{k} - x_{k-1} \right) \left( f(x_{k}) + f(x_{k-1}) \right).
\]\subsection{SymPy Support}

SymPy is a Python library for symbolic mathematics. It supports:

\begin{itemize}
\item
  polynomials
\item
  calculus
\item
  solving equations
\item
  discrete math
\item
  matrices
\end{itemize}

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{k+kn}{from} \PY{n+nn}{sympy} \PY{k+kn}{import} \PY{o}{*}
\PY{o}{\PYZpc{}}\PY{k}{load\PYZus{}ext} \PY{n}{sympyprinting}
\PY{n}{x}\PY{p}{,} \PY{n}{y} \PY{o}{=} \PY{n}{symbols}\PY{p}{(}\PY{l+s}{"}\PY{l+s}{x y}\PY{l+s}{"}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{eq} \PY{o}{=} \PY{p}{(}\PY{p}{(}\PY{n}{x}\PY{o}{+}\PY{n}{y}\PY{p}{)}\PY{o}{*}\PY{o}{*}\PY{l+m+mi}{2} \PY{o}{*} \PY{p}{(}\PY{n}{x}\PY{o}{+}\PY{l+m+mi}{1}\PY{p}{)}\PY{p}{)}
\PY{n}{eq}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{expand}\PY{p}{(}\PY{n}{eq}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{p}{(}\PY{l+m+mi}{1}\PY{o}{/}\PY{n}{cos}\PY{p}{(}\PY{n}{x}\PY{p}{)}\PY{p}{)}\PY{o}{.}\PY{n}{series}\PY{p}{(}\PY{n}{x}\PY{p}{,} \PY{l+m+mi}{0}\PY{p}{,} \PY{l+m+mi}{6}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
\subsubsection{Magic functions}

IPython has a set of predefined `magic functions' that you can call with
a command line style syntax. These include:

\begin{itemize}
\item
  \texttt{\%run}
\item
  \texttt{\%edit}
\item
  \texttt{\%debug}
\item
  \texttt{\%timeit}
\item
  \texttt{\%paste}
\item
  \texttt{\%load\_ext}
\end{itemize}

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{\PYZpc{}}\PY{k}{lsmagic}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
Timing the execution of code; the \texttt{timeit} magic exists both in
line and cell form:

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{\PYZpc{}}\PY{k}{timeit} \PY{n}{np}\PY{o}{.}\PY{n}{linalg}\PY{o}{.}\PY{n}{eigvals}\PY{p}{(}\PY{n}{np}\PY{o}{.}\PY{n}{random}\PY{o}{.}\PY{n}{rand}\PY{p}{(}\PY{l+m+mi}{100}\PY{p}{,}\PY{l+m+mi}{100}\PY{p}{)}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{\PYZpc{}\PYZpc{}}\PY{k}{timeit} \PY{n}{a} \PY{o}{=} \PY{n}{np}\PY{o}{.}\PY{n}{random}\PY{o}{.}\PY{n}{rand}\PY{p}{(}\PY{l+m+mi}{100}\PY{p}{,} \PY{l+m+mi}{100}\PY{p}{)}
\PY{n}{np}\PY{o}{.}\PY{n}{linalg}\PY{o}{.}\PY{n}{eigvals}\PY{p}{(}\PY{n}{a}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
IPython also creates aliases for a few common interpreters, such as
bash, ruby, perl, etc.

These are all equivalent to
\texttt{\%\%script \textless{}name\textgreater{}}

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{\PYZpc{}\PYZpc{}}\PY{k}{ruby}
\PY{n}{puts} \PY{l+s}{"}\PY{l+s}{Hello from Ruby \PYZsh{}\PYZob{}RUBY\PYZus{}VERSION\PYZcb{}}\PY{l+s}{"}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{\PYZpc{}\PYZpc{}}\PY{k}{bash}
\PY{n}{echo} \PY{l+s}{"}\PY{l+s}{hello from \PYZdl{}BASH}\PY{l+s}{"}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
IPython has an \texttt{rmagic} extension that contains a some magic
functions for working with R via rpy2. This extension can be loaded
using the \texttt{\%load\_ext} magic as follows:

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{\PYZpc{}}\PY{k}{load\PYZus{}ext} \PY{n}{rmagic}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{x}\PY{p}{,}\PY{n}{y} \PY{o}{=} \PY{n}{arange}\PY{p}{(}\PY{l+m+mi}{10}\PY{p}{)}\PY{p}{,} \PY{n}{random}\PY{o}{.}\PY{n}{normal}\PY{p}{(}\PY{n}{size}\PY{o}{=}\PY{l+m+mi}{10}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{\PYZpc{}\PYZpc{}}\PY{k}{R} \PY{o}{-}\PY{n}{i} \PY{n}{x}\PY{p}{,}\PY{n}{y} \PY{o}{-}\PY{n}{o} \PY{n}{XYcoef}
\PY{n}{lm}\PY{o}{.}\PY{n}{fit} \PY{o}{\PYZlt{}}\PY{o}{-} \PY{n}{lm}\PY{p}{(}\PY{n}{y}\PY{o}{\PYZti{}}\PY{n}{x}\PY{p}{)}
\PY{n}{par}\PY{p}{(}\PY{n}{mfrow}\PY{o}{=}\PY{n}{c}\PY{p}{(}\PY{l+m+mi}{2}\PY{p}{,}\PY{l+m+mi}{2}\PY{p}{)}\PY{p}{)}
\PY{k}{print}\PY{p}{(}\PY{n}{summary}\PY{p}{(}\PY{n}{lm}\PY{o}{.}\PY{n}{fit}\PY{p}{)}\PY{p}{)}
\PY{n}{plot}\PY{p}{(}\PY{n}{lm}\PY{o}{.}\PY{n}{fit}\PY{p}{)}
\PY{n}{XYcoef} \PY{o}{\PYZlt{}}\PY{o}{-} \PY{n}{coef}\PY{p}{(}\PY{n}{lm}\PY{o}{.}\PY{n}{fit}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{XYcoef}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
\subsection{Exporting and Converting Notebooks}

In IPython 1.0, one can convert an \texttt{.ipynb} notebook document
file into various static formats via the \texttt{nbconvert} tool.
Currently, nbconvert is a command line tool, run as a script using
IPython.

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{!}ipython nbconvert --to latex Section2\PYZus{}1-IPython.ipynb
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{o}{\PYZpc{}}\PY{k}{load} \PY{n}{Section2\PYZus{}1}\PY{o}{-}\PY{n}{IPython}\PY{o}{.}\PY{n}{tex}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
Currently, \texttt{nbconvert} supports HTML (default), LaTeX, Mardown,
reStructuredText, Python and HTML5 slides for presentations.A very useful online service is the
\href{http://nbviewer.ipython.org}{IPython Notebook Viewer} which allows
you to display your notebook as a static HTML page, which is useful for
sharing with others:

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{k+kn}{from} \PY{n+nn}{IPython.display} \PY{k+kn}{import} \PY{n}{HTML}
\PY{n}{HTML}\PY{p}{(}\PY{l+s}{"}\PY{l+s}{\PYZlt{}iframe src=http://nbviewer.ipython.org/4042018 width=700 height=350\PYZgt{}\PYZlt{}/iframe\PYZgt{}}\PY{l+s}{"}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
\subsection{Reproducible Research}

\begin{quote}
reproducing conclusions from a single experiment based on the
measurements from that experiment
\end{quote}

The most basic form of reproducibility is a complete description of the
data and associated analyses (including code!) so the results can be
\emph{exactly} reproduced by others.

Reproducing calculations can be onerous, even with one's own work!

Scientific data are becoming larger and more complex, making simple
descriptions inadequate for reproducibility. As a result, most modern
research is irreproducible without tremendous effort.

\emph{*} Reproducible research is not yet part of the culture of science
in general, or scientific computing in particular. \emph{*}\subsection{Scientific Computing Workflow}

There are a number of steps to scientific endeavors that involve
computing:

\begin{figure}[htbp]
\centering
\includegraphics{http://f.cl.ly/items/3B0l063n2T0H1p041U3L/workflow.png}
\caption{workflow}
\end{figure}

Many of the standard tools impose barriers between one or more of these
steps. This can make it difficult to iterate, reproduce work.

The IPython notebook eliminates or reduces these barriers to
reproducibility.\section{Parallel iPython}Before running the next cell, make sure you have first started your
cluster, you can use the \href{/\#tab2}{clusters tab in the dashboard}
to do so.

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{k+kn}{from} \PY{n+nn}{IPython.parallel} \PY{k+kn}{import} \PY{n}{Client}
\PY{n}{client} \PY{o}{=} \PY{n}{Client}\PY{p}{(}\PY{p}{)}
\PY{n}{dv} \PY{o}{=} \PY{n}{client}\PY{o}{.}\PY{n}{direct\PYZus{}view}\PY{p}{(}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n+nb}{len}\PY{p}{(}\PY{n}{dv}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{k}{def} \PY{n+nf}{where\PYZus{}am\PYZus{}i}\PY{p}{(}\PY{p}{)}\PY{p}{:}
    \PY{k+kn}{import} \PY{n+nn}{os}
    \PY{k+kn}{import} \PY{n+nn}{socket}
    
    \PY{k}{return} \PY{l+s}{"}\PY{l+s}{In process with pid \PYZob{}0\PYZcb{} on host: }\PY{l+s}{'}\PY{l+s}{\PYZob{}1\PYZcb{}}\PY{l+s}{'}\PY{l+s}{"}\PY{o}{.}\PY{n}{format}\PY{p}{(}
        \PY{n}{os}\PY{o}{.}\PY{n}{getpid}\PY{p}{(}\PY{p}{)}\PY{p}{,} \PY{n}{socket}\PY{o}{.}\PY{n}{gethostname}\PY{p}{(}\PY{p}{)}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    


    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{n}{where\PYZus{}am\PYZus{}i\PYZus{}direct\PYZus{}results} \PY{o}{=} \PY{n}{dv}\PY{o}{.}\PY{n}{apply}\PY{p}{(}\PY{n}{where\PYZus{}am\PYZus{}i}\PY{p}{)}
\PY{n}{where\PYZus{}am\PYZus{}i\PYZus{}direct\PYZus{}results}\PY{o}{.}\PY{n}{get}\PY{p}{(}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    
\subsection{Links and References}\href{http://nbviewer.ipython.org}{IPython Notebook Viewer} Displays
static HTML versions of notebooks, and includes a gallery of notebook
examples.\href{https://notebookcloud.appspot.com}{NotebookCloud} A service that
allows you to launch and control IPython Notebook servers on Amazon EC2
from your browser.\href{http://ged.msu.edu/papers/2012-diginorm/}{A Reference-Free
Algorithm for Computational Normalization of Shotgun Sequencing Data} A
landmark example of reproducible research in genomics: Git repo, iPython
notebook, data and scripts.\begin{center}\rule{3in}{0.4pt}\end{center}

    % Make sure that atleast 4 lines are below the HR
    \needspace{4\baselineskip}

    
        \vspace{6pt}
        \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-in-prompt}In\hspace{4pt}{[}54{]}:\hspace{4pt}}\\*
        \vspace{-2.65\baselineskip}
        \begin{ColorVerbatim}
            \vspace{-0.7\baselineskip}
            \begin{Verbatim}[commandchars=\\\{\}]
\PY{k+kn}{from} \PY{n+nn}{IPython.core.display} \PY{k+kn}{import} \PY{n}{HTML}
\PY{k}{def} \PY{n+nf}{css\PYZus{}styling}\PY{p}{(}\PY{p}{)}\PY{p}{:}
    \PY{n}{styles} \PY{o}{=} \PY{n+nb}{open}\PY{p}{(}\PY{l+s}{"}\PY{l+s}{styles/custom.css}\PY{l+s}{"}\PY{p}{,} \PY{l+s}{"}\PY{l+s}{r}\PY{l+s}{"}\PY{p}{)}\PY{o}{.}\PY{n}{read}\PY{p}{(}\PY{p}{)}
    \PY{k}{return} \PY{n}{HTML}\PY{p}{(}\PY{n}{styles}\PY{p}{)}
\PY{n}{css\PYZus{}styling}\PY{p}{(}\PY{p}{)}
\end{Verbatim}

            
                \vspace{-0.2\baselineskip}
            
        \end{ColorVerbatim}
    

    

        % If the first block is an image, minipage the image.  Else
        % request a certain amount of space for the input text.
        \needspace{4\baselineskip}
        
        

            % Add document contents.
            
                \makebox[0.1\linewidth]{\smaller\hfill\tt\color{nbframe-out-prompt}Out\hspace{4pt}{[}54{]}:\hspace{4pt}}\\*
                \vspace{-2.55\baselineskip}\begin{InvisibleVerbatim}
                \vspace{-0.5\baselineskip}
\begin{alltt}<IPython.core.display.HTML object at 0x1162617d0>\end{alltt}

            \end{InvisibleVerbatim}
            
        
    

        

        \renewcommand{\indexname}{Index}
        \printindex

    % End of document
    \end{document}

# %% [markdown]
# Currently, `nbconvert` supports HTML (default), LaTeX, Mardown, reStructuredText, Python and HTML5 slides for presentations.

# %% [markdown]
# A very useful online service is the [IPython Notebook Viewer](http://nbviewer.ipython.org) which allows you to display your notebook as a static HTML page, which is useful for sharing with others:

# %%
from IPython.display import HTML
HTML("<iframe src=http://nbviewer.ipython.org/4042018 width=700 height=350></iframe>")
# Out:
# <iframe src=http://nbviewer.ipython.org/4042018 width=700 height=350></iframe>

# %% [markdown]
# ## Reproducible Research
#
# > reproducing conclusions from a single experiment based on the measurements from that experiment
#
# The most basic form of reproducibility is a complete description of the data and associated analyses (including code!) so the results can be *exactly* reproduced by others.
#
# Reproducing calculations can be onerous, even with one's own work!
#
# Scientific data are becoming larger and more complex, making simple descriptions inadequate for reproducibility. As a result, most modern research is irreproducible without tremendous effort.
#
# *** Reproducible research is not yet part of the culture of science in general, or scientific computing in particular. ***

# %% [markdown]
# ## Scientific Computing Workflow
#
# There are a number of steps to scientific endeavors that involve computing:
#
# ![workflow](http://f.cl.ly/items/3B0l063n2T0H1p041U3L/workflow.png)
#
# Many of the standard tools impose barriers between one or more of these steps. This can make it difficult to iterate, reproduce work.
#
# The IPython notebook eliminates or reduces these barriers to reproducibility.

# %% [markdown]
# ## Parallel iPython

# %% [markdown]
# Before running the next cell, make sure you have first started your cluster, you can use the [clusters tab in the dashboard](/#tab2) to do so.

# %%
from IPython.parallel import Client
client = Client()
dv = client.direct_view()

# %%
len(dv)
# Out:
# 2

# %%
def where_am_i():
    import os
    import socket
    
    return "In process with pid {0} on host: '{1}'".format(
        os.getpid(), socket.gethostname())

# %%
where_am_i_direct_results = dv.apply(where_am_i)
where_am_i_direct_results.get()
# Out:
# [In process with pid 10298 on host: 'cepeda.dhcp.mc.vanderbilt.edu',
#  In process with pid 10303 on host: 'cepeda.dhcp.mc.vanderbilt.edu']

# %% [markdown]
# ## Links and References

# %% [markdown]
# [IPython Notebook Viewer](http://nbviewer.ipython.org) Displays static HTML versions of notebooks, and includes a gallery of notebook examples.

# %% [markdown]
# [NotebookCloud](https://notebookcloud.appspot.com) A service that allows you to launch and control IPython Notebook servers on Amazon EC2 from your browser.

# %% [markdown]
# [A Reference-Free Algorithm for Computational Normalization of Shotgun Sequencing Data](http://ged.msu.edu/papers/2012-diginorm/) A landmark example of reproducible research in genomics: Git repo, iPython notebook, data and scripts.

# %% [markdown]
# ---

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
# /*        margin-left:16% !important;*/
#         margin-left:auto;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
